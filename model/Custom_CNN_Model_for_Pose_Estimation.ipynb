# %% [markdown]
# ## Import Modules

# %%
# %%capture
# !pip install tensorflow_model_optimization

# %%
import os
import re
from collections import defaultdict
import shutil
import json
import random
from ast import literal_eval

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.collections import LineCollection

import cv2

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D, BatchNormalization, Flatten, Dropout, LeakyReLU
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.losses import mean_squared_error

from sklearn.model_selection import train_test_split

import tensorflow_model_optimization as tfmot
import tensorflow as tf
from tqdm.notebook import tqdm

# %% [markdown]
# ### Helper functions

# %%
def read_image(img_loc: str, channel: "gray or rgb"="gray"):
    channel = channel.lower()
    assert channel in ["gray", "rgb"]
    image = cv2.imread(img_loc)
    if channel == "rgb":
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    else:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = np.expand_dims(image, axis=-1)
        image = np.repeat(image, 3, axis=-1)
        height, width, channel = image.shape
    return image

# %%
def display_image(image: "image_loc or numpy.ndarray", ratio:int=5, **kwargs):
    assert isinstance(image, str) or isinstance(image, np.ndarray)
    channel = kwargs.get("channel", "gray")
    if isinstance(image, str):
        image = read_image(image, channel)
#     else:
#         if channel == "gray": image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    assert isinstance(image, np.ndarray)
    height, width = image.shape[0], image.shape[1]
    aspect_ratio = float(width) / height
    fig, ax = plt.subplots(figsize=(ratio*aspect_ratio, ratio))
    fig.tight_layout(pad=0)
    ax.margins(0)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    plt.axis('off')
    cmap = channel if channel == "gray" else "viridis"
    ax.imshow(image, cmap=cmap)
    return ax

# %%
def get_line_segments(x):
    groups = [
        ["left_shoulder", "left_elbow"],
        ["left_elbow", "left_wrist"],
        ["right_shoulder", "right_elbow"],
        ["right_elbow", "right_wrist"],
        ["left_ankle", "left_knee"],
        ["left_knee", "left_hip"],
        ["right_ankle", "right_knee"],
        ["right_knee", "right_hip"],
        ["left_shoulder", "right_shoulder"],
        ["left_hip", "right_hip"]
    ]
    
    lines = []
    for i in groups:
        if x[i[0]][0] != -1 and x[i[1]][0] != -1:
            lines.append([x[i[0]], x[i[1]]])
    if x[groups[-2][0]][0] != -1 and x[groups[-2][1]][0] != -1:
        if x[groups[-1][0]][0] != -1 and x[groups[-1][1]][0] != -1:
            lines.append([
                [(x[groups[-2][0]][0] + x[groups[-2][1]][0])/2, (x[groups[-2][0]][1] + x[groups[-2][1]][1])/2],
                [(x[groups[-1][0]][0] + x[groups[-1][1]][0])/2, (x[groups[-1][0]][1] + x[groups[-1][1]][1])/2]
            ])
    return lines

# %%
def display_image_with_pose(image: "image_loc or numpy.ndarray", pose: "pandas.core.frame.DataFrame", ratio:int=5, **kwargs):
    ax = display_image(image, ratio, **kwargs)
    line_segments = LineCollection([], linewidths=(3), linestyle='solid', color='red')
    ax.add_collection(line_segments)
    temp = get_line_segments(pose)
#     temp = pose.apply(lambda x: get_line_segments(x), axis=1).to_list()[0]
    dots = list(set((j[0], j[1]) for i in temp for j in i))
    line_segments.set_segments(temp)
    for i in dots:
        plt.scatter(i[0], i[1], s=20, zorder=3, color='white')
    return ax

# %%
def datapoint_correction(x):
    temp = []
    for i in x:
        if i[0] == -1 or i[1] == -1:
            temp.append((-1, -1))
        else:
            temp.append(i)
    return pd.Series(temp)

# %% [markdown]
# ### Define variables and directories

# %%
BASE_DIR = "/content/drive/MyDrive/CNN/Regressor"
DATA_DIR = os.path.join(BASE_DIR, "data")
INPUT_DIR = os.path.join(DATA_DIR, "inputs", "gray_ch_1_224")
ANNOTATION = os.path.join(INPUT_DIR.replace("inputs", "annotations"), "final_model_ready_dataset.csv")

# %% [markdown]
# ### Load feature space and labels

# %%
X_data = np.load(os.path.join(INPUT_DIR, "X_data.npy"))
Y_data = np.load(os.path.join(INPUT_DIR, "Y_data.npy"))

# %% [markdown]
# ### Perform preprocessing before passing to model for training

# %%
# If input has one channel, repeat the channel value 3 times - for 3 channel input
if X_data.shape[-1] == 1:
    X_data = np.repeat(X_data, 3, axis=-1)

# Normalize the keypoint coordinates between 0 and 1
# if Y_data.dtype == int:
#     Y_data = Y_data/X_data.shape[1]

# Reshape Y to match output shape
# Y_data = Y_data.reshape((Y_data.shape[0], 1, 1, Y_data.shape[-1]))

print("INPUT SHAPE:", X_data.shape, "\nOUTPUT_SHAPE:", Y_data.shape)
# Out:
# INPUT SHAPE: (11232, 224, 224, 3)
# OUTPUT_SHAPE: (11232, 24)

# %% [markdown]
# ## Split dataset into train and test set

# %%
X_data = (X_data/255).astype('float16')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=2022)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
del X_data, Y_data

# %% [markdown]
# ## Define model's parameters and hyperparameters

# %%
BATCH_SIZE = 64
LEARNING_RATE = 1e-4
EPOCHS = 500

# %% [markdown]
# ## POSE ESTIMATOR MODEL

# %% [markdown]
# ### Define model architecture

# %%
model = Sequential([
                    Input(shape=X_train.shape[1:], name="INPUT"),
                    Conv2D(filters=32, kernel_size=[5,5],padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    
                    Conv2D(filters=32, kernel_size=[5,5], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    MaxPool2D(pool_size=[2,2]),
                    
                    Conv2D(filters=64, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    Conv2D(filters=64, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    MaxPool2D(pool_size=[2,2]),
                    
                    Conv2D(filters=128, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    Conv2D(filters=128, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    MaxPool2D(pool_size=[2,2]),
                    
                    Conv2D(filters=256, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    Conv2D(filters=256, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    MaxPool2D(pool_size=[2,2]),
                    Dropout(.3),

                    Conv2D(filters=512, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    Conv2D(filters=512, kernel_size=[3,3], padding='same', use_bias=False),
                    LeakyReLU(alpha = .1),
                    BatchNormalization(),
                    
                    Flatten(),
                    Dense(units=512, activation='relu'),
                    Dropout(.3),
                    Dense(units=Y_test.shape[-1]),
], name="Pose_Estimator")
model.summary()
# Out:
# Model: "Pose_Estimator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      2400
#
#  leaky_re_lu (LeakyReLU)     (None, 224, 224, 32)      0
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      25600
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 224, 224, 32)      0
#
#  batch_normalization_1 (Batc  (None, 224, 224, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)      18432
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 112, 112, 64)      0
#
#  batch_normalization_2 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 64)      36864
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 112, 112, 64)      0
#
#  batch_normalization_3 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 128)       73728
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 56, 56, 128)       0
#
#  batch_normalization_4 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)       147456
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 56, 56, 128)       0
#
#  batch_normalization_5 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 256)       294912
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 28, 28, 256)       0
#
#  batch_normalization_6 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 256)       589824
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 28, 28, 256)       0
#
#  batch_normalization_7 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  dropout (Dropout)           (None, 14, 14, 256)       0
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 512)       1179648
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 14, 14, 512)       0
#
#  batch_normalization_8 (Batc  (None, 14, 14, 512)      2048
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 512)       2359296
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 14, 14, 512)       0
#
#  batch_normalization_9 (Batc  (None, 14, 14, 512)      2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 512)               51380736
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 24)                12312
#
# =================================================================
# Total params: 56,129,144
# Trainable params: 56,125,176
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
# inputs = Input(shape=X_train.shape[1:], name="INPUT")
# # x = tf.keras.applications.mobilenet_v3.preprocess_input(inputs)
# x = backbone(inputs)
# x = tf.keras.layers.SeparableConv2D(Y_train.shape[-1], kernel_size=3, strides=1, activation="relu")(x)
# x = tf.keras.layers.SeparableConv2D(Y_train.shape[-1], kernel_size=3, strides=1, activation="relu")(x)
# x = tf.keras.layers.SeparableConv2D(Y_train.shape[-1], kernel_size=3, strides=1, activation="relu")(x)
# x = tf.keras.layers.SeparableConv2D(Y_train.shape[-1], kernel_size=1, strides=1, activation="relu")(x)
# x = tf.keras.layers.SeparableConv2D(Y_train.shape[-1], kernel_size=1, strides=1, activation="relu")(x)
# outputs = tf.keras.layers.SeparableConv2D(Y_train.shape[-1], kernel_size=1, strides=1, activation="relu")(x)

# model = tf.keras.Model(inputs=inputs, outputs=outputs, name="Pose_Estimator")
# model.summary()

# %% [markdown]
# ### Plot model

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ### Compile model

# %%
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss=tf.keras.losses.mean_squared_error,
    # metrics=['mae', 'mape',],
    metrics=['mae'],
)

# %% [markdown]
# ### Define callbacks

# %%
CALLBACKS = [ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=8,
    verbose=1,
    min_lr=LEARNING_RATE*1e-5,
    mode='auto',
    cooldown=0,
    min_delta=0.0001
)]
CALLBACKS += [EarlyStopping(
    monitor='val_loss',
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode='min',
    baseline=None,
    restore_best_weights=True
)]

# %% [markdown]
# ### Train and evaluate model

# %%
# Y_train = Y_train.reshape(Y_train.shape[0], Y_train.shape[-1])
# Y_test = Y_test.reshape(Y_test.shape[0], Y_test.shape[-1])

# %%
history = model.fit(X_train, Y_train,
                    epochs = EPOCHS,
                    validation_data = (X_test, Y_test),
                    batch_size = BATCH_SIZE,
                    callbacks = [CALLBACKS],
                    )
# Out:
# Epoch 1/500
# 141/141 [==============================] - 28s 165ms/step - loss: 1904.3755 - mae: 32.3308 - val_loss: 5725.4390 - val_mae: 65.8574 - lr: 1.0000e-04
# Epoch 2/500
# 141/141 [==============================] - 20s 144ms/step - loss: 964.8642 - mae: 23.9440 - val_loss: 2083.5508 - val_mae: 36.6696 - lr: 1.0000e-04
# Epoch 3/500
# 141/141 [==============================] - 20s 144ms/step - loss: 857.9385 - mae: 22.4789 - val_loss: 1227.0630 - val_mae: 27.4087 - lr: 1.0000e-04
# Epoch 4/500
# 141/141 [==============================] - 20s 145ms/step - loss: 763.4706 - mae: 21.1427 - val_loss: 773.1945 - val_mae: 21.1386 - lr: 1.0000e-04
# Epoch 5/500
# 141/141 [==============================] - 20s 145ms/step - loss: 694.7104 - mae: 20.1283 - val_loss: 651.3088 - val_mae: 18.8663 - lr: 1.0000e-04
# Epoch 6/500
# 141/141 [==============================] - 20s 144ms/step - loss: 631.8156 - mae: 19.1981 - val_loss: 685.4677 - val_mae: 19.1776 - lr: 1.0000e-04
# Epoch 7/500
# 141/141 [==============================] - 20s 145ms/step - loss: 579.6472 - mae: 18.3914 - val_loss: 615.6492 - val_mae: 18.1147 - lr: 1.0000e-04
# Epoch 8/500
# 141/141 [==============================] - 20s 144ms/step - loss: 533.0015 - mae: 17.6669 - val_loss: 642.9205 - val_mae: 18.7432 - lr: 1.0000e-04
# Epoch 9/500
# 141/141 [==============================] - 20s 144ms/step - loss: 490.2373 - mae: 16.9480 - val_loss: 588.6335 - val_mae: 17.6931 - lr: 1.0000e-04
# Epoch 10/500
# 141/141 [==============================] - 20s 143ms/step - loss: 456.0512 - mae: 16.4010 - val_loss: 654.3860 - val_mae: 18.9804 - lr: 1.0000e-04
# Epoch 63/500
# 141/141 [==============================] - ETA: 0s - loss: 205.7798 - mae: 11.1553Restoring model weights from the end of the best epoch: 43.
# 141/141 [==============================] - 20s 145ms/step - loss: 205.7798 - mae: 11.1553 - val_loss: 557.2105 - val_mae: 17.0844 - lr: 1.0000e-08
# Epoch 63: early stopping

# %% [markdown]
# ## Make predictions

# %%
input()

# %%
predicted = model.predict(X_test)

# %%
# new_pred = (predicted * X_test.shape[1]).astype('int')
new_pred = predicted.astype('int')
new_pred = np.where(new_pred < 1, -1, new_pred)
new_pred = new_pred.reshape((new_pred.shape[0], new_pred.shape[-1]))
new_pred.shape
# Out:
# (2247, 24)

# %%
data = []
for i in new_pred:
    temp = i.tolist()
    data.append([(temp[j], temp[j+1]) for j in range(0, 24, 2)])

pd_test = pd.DataFrame(data)
columns = pd.read_csv(ANNOTATION).columns[1:-7]
pd_test.columns = columns

pd_test = pd_test.apply(lambda x: datapoint_correction(x), axis=1)
pd_test.columns = columns
pd_test.head()
# Out:
#   left_shoulder right_shoulder  left_elbow right_elbow  left_wrist  \
# 0     (119, 81)      (100, 80)   (111, 98)    (96, 93)   (115, 97)
# 1    (128, 127)     (125, 125)  (125, 153)  (126, 165)  (125, 162)
# 2     (65, 110)      (65, 113)   (66, 129)   (59, 135)   (65, 137)
# 3     (138, 59)      (129, 53)   (138, 73)   (117, 62)   (135, 81)
# 4     (165, 70)      (136, 61)  (140, 100)    (96, 79)   (92, 105)
#
#   right_wrist    left_hip   right_hip   left_knee  right_knee  left_ankle  \
# 0   (115, 92)  (104, 116)   (95, 111)  (105, 124)   (98, 125)  (103, 145)
# 1  (136, 174)  (106, 157)  (101, 155)   (94, 164)  (101, 166)   (69, 185)
# 2   (63, 146)  (125, 114)  (123, 122)  (151, 118)  (155, 128)  (199, 127)
# 3   (108, 71)  (125, 104)   (115, 99)  (112, 148)   (94, 135)  (112, 192)
# 4    (60, 90)  (181, 143)  (152, 134)  (117, 146)   (82, 136)   (94, 188)
#
#   right_ankle
# 0  (111, 157)
# 1   (81, 190)
# 2  (196, 128)
# 3   (77, 188)
# 4   (69, 183)

# %%
i = 4
# display_image_with_pose(np.repeat(X_train[i], 3, axis=-1), temp_data.iloc[i])
display_image((X_test[i]*255).astype('int'))
display_image_with_pose((X_test[i]).astype('int'), pd_test.iloc[i])

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('Baseline test mae:', mean_absolute_error(Y_test, new_pred))
# Out:
# Baseline test mae: 16.983737576027295

# %% [markdown]
# ## Pruning

# %%
port_img = cv2.resize(cv2.imread("me/00001.jpg"), (224, 224), interpolation=cv2.INTER_AREA)
port_pred = model.predict(np.expand_dims(port_img, axis=0)).astype('int').flatten()
port_pred = np.where(port_pred < 1, -1, port_pred)
port_pred = np.where(port_pred > 224, -1, port_pred)

data = []
for i in [port_pred]:
    temp = i.tolist()
    data.append([(temp[j], temp[j+1]) for j in range(0, 24, 2)])

pd_test = pd.DataFrame(data)
columns = pd.read_csv(ANNOTATION).columns[1:-7]
pd_test.columns = columns

pd_test = pd_test.apply(lambda x: datapoint_correction(x), axis=1)
pd_test.columns = columns
display_image(port_img)
display_image_with_pose(np.zeros(224*224*3).reshape(224,224,3).astype('int'), pd_test.iloc[0], ratio=5)

# %%
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

prune_epochs = 10

end_step = np.ceil(1.0 * X_train.shape[0] / BATCH_SIZE).astype(np.int32) * prune_epochs
# Define model for pruning.
pruning_params = {
    'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(
        initial_sparsity=0.50,
        final_sparsity=0.90,
        begin_step=0,
        end_step=end_step
        ),
    }
model_for_pruning = prune_low_magnitude(model, **pruning_params)
# `prune_low_magnitude` requires a recompile.
model_for_pruning.compile(
    loss = 'mse',
    optimizer = Adam(),
    metrics = ['mae'],
)

model_for_pruning.summary()

pruning_history = model_for_pruning.fit(X_train, Y_train,
                    epochs=prune_epochs,
                    validation_data=(X_test, Y_test), 
                    # batch_size=BATCH_SIZE,
                    callbacks=[tfmot.sparsity.keras.UpdatePruningStep()],
                    )
model_for_pruning.save("pruned_multiclass")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:218: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   aggregation=tf.VariableAggregation.MEAN)
# /usr/local/lib/python3.7/dist-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:225: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   aggregation=tf.VariableAggregation.MEAN)
# /usr/local/lib/python3.7/dist-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:238: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   trainable=False)
# Model: "Pose_Estimator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  prune_low_magnitude_conv2d   (None, 224, 224, 32)     4802
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 224, 224, 32)     1
#  e_lu (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 224, 224, 32)     129
#  ormalization (PruneLowMagni
#  tude)
#
#  prune_low_magnitude_conv2d_  (None, 224, 224, 32)     51202
#  1 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 224, 224, 32)     1
#  e_lu_1 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 224, 224, 32)     129
#  ormalization_1 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_max_poo  (None, 112, 112, 32)     1
#  ling2d (PruneLowMagnitude)
#
#  prune_low_magnitude_conv2d_  (None, 112, 112, 64)     36866
#  2 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 112, 112, 64)     1
#  e_lu_2 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 112, 112, 64)     257
#  ormalization_2 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_conv2d_  (None, 112, 112, 64)     73730
#  3 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 112, 112, 64)     1
#  e_lu_3 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 112, 112, 64)     257
#  ormalization_3 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_max_poo  (None, 56, 56, 64)       1
#  ling2d_1 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_conv2d_  (None, 56, 56, 128)      147458
#  4 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 56, 56, 128)      1
#  e_lu_4 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 56, 56, 128)      513
#  ormalization_4 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_conv2d_  (None, 56, 56, 128)      294914
#  5 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 56, 56, 128)      1
#  e_lu_5 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 56, 56, 128)      513
#  ormalization_5 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_max_poo  (None, 28, 28, 128)      1
#  ling2d_2 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_conv2d_  (None, 28, 28, 256)      589826
#  6 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 28, 28, 256)      1
#  e_lu_6 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 28, 28, 256)      1025
#  ormalization_6 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_conv2d_  (None, 28, 28, 256)      1179650
#  7 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 28, 28, 256)      1
#  e_lu_7 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 28, 28, 256)      1025
#  ormalization_7 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_max_poo  (None, 14, 14, 256)      1
#  ling2d_3 (PruneLowMagnitude
#  )
#
#  prune_low_magnitude_dropout  (None, 14, 14, 256)      1
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_conv2d_  (None, 14, 14, 512)      2359298
#  8 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 14, 14, 512)      1
#  e_lu_8 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 14, 14, 512)      2049
#  ormalization_8 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_conv2d_  (None, 14, 14, 512)      4718594
#  9 (PruneLowMagnitude)
#
#  prune_low_magnitude_leaky_r  (None, 14, 14, 512)      1
#  e_lu_9 (PruneLowMagnitude)
#
#  prune_low_magnitude_batch_n  (None, 14, 14, 512)      2049
#  ormalization_9 (PruneLowMag
#  nitude)
#
#  prune_low_magnitude_flatten  (None, 100352)           1
#   (PruneLowMagnitude)
#
#  prune_low_magnitude_dense (  (None, 512)              102760962
#  PruneLowMagnitude)
#
#  prune_low_magnitude_dropout  (None, 512)              1
#  _1 (PruneLowMagnitude)
#
#  prune_low_magnitude_dense_1  (None, 24)               24602
#   (PruneLowMagnitude)
#
# =================================================================
# Total params: 112,249,867
# Trainable params: 56,125,176
# Non-trainable params: 56,124,691
# _________________________________________________________________
# Epoch 1/10
# 281/281 [==============================] - 37s 98ms/step - loss: 1355.6354 - mae: 28.1654 - val_loss: 1622.8928 - val_mae: 30.5404
# Epoch 2/10
# 281/281 [==============================] - 26s 93ms/step - loss: 1077.1676 - mae: 25.2530 - val_loss: 751.5776 - val_mae: 20.7249
# Epoch 3/10
# 281/281 [==============================] - 26s 93ms/step - loss: 1012.5064 - mae: 24.5228 - val_loss: 775.9225 - val_mae: 21.1331
# Epoch 4/10
# 281/281 [==============================] - 26s 93ms/step - loss: 971.9481 - mae: 23.9891 - val_loss: 689.6357 - val_mae: 19.6139
# Epoch 5/10
# 281/281 [==============================] - 26s 93ms/step - loss: 937.9643 - mae: 23.5685 - val_loss: 692.2904 - val_mae: 19.5310
# Epoch 6/10
# 281/281 [==============================] - 25s 88ms/step - loss: 892.8620 - mae: 22.9777 - val_loss: 612.9382 - val_mae: 18.1877
# Epoch 7/10
# 281/281 [==============================] - 25s 88ms/step - loss: 860.8081 - mae: 22.5576 - val_loss: 613.6543 - val_mae: 18.2055
# Epoch 8/10
# 281/281 [==============================] - 25s 88ms/step - loss: 841.0995 - mae: 22.3023 - val_loss: 598.6346 - val_mae: 17.8091
# Epoch 9/10
# 281/281 [==============================] - 25s 88ms/step - loss: 812.5943 - mae: 21.9210 - val_loss: 579.0266 - val_mae: 17.5491
# Epoch 10/10
# 281/281 [==============================] - 25s 88ms/step - loss: 785.6940 - mae: 21.5849 - val_loss: 591.2307 - val_mae: 17.6698
# WARNING:absl:Function `_wrapped_model` contains input name(s) INPUT with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, leaky_re_lu_layer_call_fn, leaky_re_lu_layer_call_and_return_conditional_losses, conv2d_1_layer_call_fn while saving (showing 5 of 50). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: pruned_multiclass/assets
# INFO:tensorflow:Assets written to: pruned_multiclass/assets

# %% [markdown]
# ### Make predictions on pruned model

# %%
prun_pred = model_for_pruning.predict(X_test)
prun_pred = prun_pred.astype('int')
prun_pred = np.where(prun_pred < 1, -1, prun_pred)
prun_pred = prun_pred.reshape((prun_pred.shape[0], prun_pred.shape[-1]))
prun_pred.shape
# Out:
# (2247, 24)

# %%
print('Baseline test mae:', mean_absolute_error(Y_test, new_pred))
print('Pruned test mae:', mean_absolute_error(Y_test, prun_pred))
# Out:
# Baseline test mae: 16.983737576027295
# Pruned test mae: 17.735258121940365

# %% [markdown]
# ## Quantize Model

# %%
X_train_dataset = tf.data.Dataset.from_tensor_slices((X_train/255).astype('float32'))

# get the pruned model ready
model_for_export = tfmot.sparsity.keras.strip_pruning(model_for_pruning)

# quantize
converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

num_calibration_steps = 1
def representative_data_gen():
    for input_value in X_train_dataset.batch(1).take(100):
        yield [input_value]

converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8  # or tf.uint8
converter.inference_output_type = tf.int8  # or tf.uint8

# %%
tflite_model = converter.convert()
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) INPUT with unsupported characters which will be renamed to input in the SavedModel.
# INFO:tensorflow:Assets written to: /tmp/tmp_c2yd6qt/assets
# INFO:tensorflow:Assets written to: /tmp/tmp_c2yd6qt/assets
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
with open("quant_pruned.tflite",'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ### Make predictions on quantized model

# %%
interpreter = tf.lite.Interpreter("quant_pruned.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on random input data.
input_shape = input_details[0]['shape']
quant_pred = []

pbar = tqdm(total=5, desc="Making predictions on tflite model:")
for i in range(5):
    input_data = np.expand_dims((X_test[0]*255).astype('int8'), axis=0)
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()
    pbar.update(1)
    
    # The function `get_tensor()` returns a copy of the tensor data.
    # Use `tensor()` in order to get a pointer to the tensor.
    output_data = interpreter.get_tensor(output_details[0]['index'])
    quant_pred.append(output_data.flatten())
quant_pred = np.array(quant_pred)
pbar.close()
# Out:
# Making predictions on tflite model::   0%|          | 0/5 [00:00<?, ?it/s]
